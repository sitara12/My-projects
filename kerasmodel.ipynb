# %% [markdown]
# <a href="https://colab.research.google.com/github/sitara12/My-projects/blob/main/kerasmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the dataset
df = pd.read_csv("diabetes.csv")

# Define the correct column names
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df.columns = columns

# Assuming you have a 'dataset' variable, you should change it to 'df.values'
X = df.values[:, 0:8]
y = df.values[:, 8]

# Define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 0.8495 - accuracy: 0.6549
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.6602
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6377 - accuracy: 0.6654
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6282 - accuracy: 0.6719
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6222 - accuracy: 0.6771
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6108 - accuracy: 0.6836
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6875
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6103 - accuracy: 0.6901
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5979 - accuracy: 0.7018
# Epoch 10/150
# ...
